# %% [markdown]
# <a href="https://colab.research.google.com/github/mohyunyang/My_Kaggle/blob/main/(Step2)Bike_Sharing_Demand.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle
from google.colab import files
files.upload()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.6.15)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
#      <input type="file" id="files-6c75ecc8-07c3-456e-b21a-132ca5262384" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c75ecc8-07c3-456e-b21a-132ca5262384">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"yhyunmo","key":"8fdb7bbf0193b24d0178986819fcf478"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
! kaggle competitions download -c bike-sharing-demand
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading bike-sharing-demand.zip to /content
#   0% 0.00/189k [00:00<?, ?B/s]
# 100% 189k/189k [00:00<00:00, 67.2MB/s]

# %%
# !unzip bike-sharing-demand.zip
# Out:
# Archive:  bike-sharing-demand.zip
#   inflating: sampleSubmission.csv
#   inflating: test.csv
#   inflating: train.csv

# %% [markdown]
# # 1. 데이터 불러오기

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test.head() #
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
# 이상치제거 weather = 4가 아닌 것들만 추출
train = train[train['weather']!=4]

# %%
all_data_temp = pd.concat([train, test])
all_data_temp
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed  casual  registered  count        date  \
# 0     14.395        81     0.0000     3.0        13.0   16.0  2011-01-01
# 1     13.635        80     0.0000     8.0        32.0   40.0  2011-01-01
# 2     13.635        80     0.0000     5.0        27.0   32.0  2011-01-01
# 3     14.395        75     0.0000     3.0        10.0   13.0  2011-01-01
# 4     14.395        75     0.0000     0.0         1.0    1.0  2011-01-01
# ...      ...       ...        ...     ...         ...    ...         ...
# 6488  12.880        60    11.0014     NaN         NaN    NaN         NaN
# 6489  12.880        60    11.0014     NaN         NaN    NaN         NaN
# 6490  12.880        60    11.0014     NaN         NaN    NaN         NaN
# 6491  13.635        56     8.9981     NaN         NaN    NaN         NaN
# 6492  13.635        65     8.9981     NaN         NaN    NaN         NaN
#
#       year month hour
# 0     2011    01   00
# 1     2011    01   01
# 2     2011    01   02
# 3     2011    01   03
# 4     2011    01   04
# ...    ...   ...  ...
# 6488   NaN   NaN  NaN
# 6489   NaN   NaN  NaN
# 6490   NaN   NaN  NaN
# 6491   NaN   NaN  NaN
# 6492   NaN   NaN  NaN
#
# [17379 rows x 16 columns]

# %%
all_data = pd.concat([train, test], ignore_index = True)
all_data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 17374  2012-12-31 19:00:00       1        0           1        2  10.66
# 17375  2012-12-31 20:00:00       1        0           1        2  10.66
# 17376  2012-12-31 21:00:00       1        0           1        1  10.66
# 17377  2012-12-31 22:00:00       1        0           1        1  10.66
# 17378  2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count        date  \
# 0      14.395        81     0.0000     3.0        13.0   16.0  2011-01-01
# 1      13.635        80     0.0000     8.0        32.0   40.0  2011-01-01
# 2      13.635        80     0.0000     5.0        27.0   32.0  2011-01-01
# 3      14.395        75     0.0000     3.0        10.0   13.0  2011-01-01
# 4      14.395        75     0.0000     0.0         1.0    1.0  2011-01-01
# ...       ...       ...        ...     ...         ...    ...         ...
# 17374  12.880        60    11.0014     NaN         NaN    NaN         NaN
# 17375  12.880        60    11.0014     NaN         NaN    NaN         NaN
# 17376  12.880        60    11.0014     NaN         NaN    NaN         NaN
# 17377  13.635        56     8.9981     NaN         NaN    NaN         NaN
# 17378  13.635        65     8.9981     NaN         NaN    NaN         NaN
#
#        year month hour
# 0      2011    01   00
# 1      2011    01   01
# 2      2011    01   02
# 3      2011    01   03
# 4      2011    01   04
# ...     ...   ...  ...
# 17374   NaN   NaN  NaN
# 17375   NaN   NaN  NaN
# 17376   NaN   NaN  NaN
# 17377   NaN   NaN  NaN
# 17378   NaN   NaN  NaN
#
# [17379 rows x 16 columns]

# %%
# 파생피처 추가
from datetime import datetime

# 날짜 피처 생성
print(all_data['datetime'][0])
print(all_data['datetime'][0].split())
print(all_data['datetime'][0].split()[0])

all_data['date'] = all_data['datetime'].apply( lambda x : x.split()[0])
print(all_data['date'][0])

# 년
all_data['year'] = all_data['date'].apply( lambda x : x.split('-')[0])
print(all_data['year'][0])

# 월
all_data['month'] = all_data['date'].apply( lambda x : x.split('-')[1])
print(all_data['month'][0])

# 시간
all_data['hour'] = all_data['datetime'].apply( lambda x : x.split()[1].split(':')[0])
print(all_data['hour'][0])

# 요일
all_data['weekday'] = all_data['date'].apply( lambda x : datetime.strptime(x, '%Y-%m-%d').weekday())
print(all_data['weekday'][0])
# Out:
# 2011-01-01 00:00:00
# ['2011-01-01', '00:00:00']
# 2011-01-01
# 2011-01-01
# 2011
# 01
# 00
# 5

# %%
all_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count        date  year month  \
# 0        81        0.0     3.0        13.0   16.0  2011-01-01  2011    01
# 1        80        0.0     8.0        32.0   40.0  2011-01-01  2011    01
# 2        80        0.0     5.0        27.0   32.0  2011-01-01  2011    01
# 3        75        0.0     3.0        10.0   13.0  2011-01-01  2011    01
# 4        75        0.0     0.0         1.0    1.0  2011-01-01  2011    01
#
#   hour  weekday
# 0   00        5
# 1   01        5
# 2   02        5
# 3   03        5
# 4   04        5

# %%
# 피쳐제거
drop_features = ['casual', 'registered', 'datetime', 'date', 'month', 'windspeed']
all_data = all_data.drop(drop_features, axis=1)
all_data.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  count  year  \
# 0       1        0           0        1  9.84  14.395        81   16.0  2011
# 1       1        0           0        1  9.02  13.635        80   40.0  2011
# 2       1        0           0        1  9.02  13.635        80   32.0  2011
# 3       1        0           0        1  9.84  14.395        75   13.0  2011
# 4       1        0           0        1  9.84  14.395        75    1.0  2011
#
#   hour  weekday
# 0   00        5
# 1   01        5
# 2   02        5
# 3   03        5
# 4   04        5

# %%
# 데이터 나누기 ('count'가 있는 건 train, 없는건 test)
X_train = all_data[~pd.isnull(all_data['count'])]
X_test = all_data[pd.isnull(all_data['count'])]

# %%
X_train

# %%
X_test

# %%
# 'count' 제거
X_train = X_train.drop('count', axis=1)
X_test = X_test.drop('count', axis=1)

# %%
# 타겟값
y = train['count']

# %% [markdown]
# # 2. 모델훈련

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()

log_y = np.log(y) # 로그변환
lr_model.fit(X_train, log_y) # 모델훈련
# Out:
# LinearRegression()

# %%
# 모델 성능 검증
pred = lr_model.predict(X_train)
pred[:5]
# Out:
# array([2.19530587, 2.2789835 , 2.38245985, 2.59663105, 2.7001074 ])

# %%
import numpy as np

def rmsle(y_true, y_pred, convertExp=True):
  # 지수변환
  if convertExp:
    y_true = np.exp(y_true) # exp : 지수변환 np함수
    y_pred = np.exp(y_pred)
  
  # 로그변환 후 결측값을 0으로 변환
  log_ture = np.nan_to_num(np.log(y_true+1)) # np.nan_to_num : 결측값을 0으로 바꾸는 np함수
  log_pred = np.nan_to_num(np.log(y_pred+1))  

  # RMSLE 계산
  output = np.sqrt(np.mean((log_ture - log_pred)**2))
  return output

# %%
print(f'선형회귀의 RMSLE 값 : {rmsle(log_y, pred, True):.4f}')
# Out:
# 선형회귀의 RMSLE 값 : 1.0205

# %% [markdown]
# # 3. 예측 및 결과 제출

# %%
submission = pd.read_csv('sampleSubmission.csv')

# %%
lr_preds = lr_model.predict(X_test)
lr_preds[:5]

submission['count'] = np.exp(lr_preds)
submission.to_csv('.submission.csv', index=False)

# %%
submission
# Out:
#                  datetime       count
# 0     2011-01-20 00:00:00   11.359338
# 1     2011-01-20 01:00:00   13.599085
# 2     2011-01-20 02:00:00   15.081651
# 3     2011-01-20 03:00:00   16.305721
# 4     2011-01-20 04:00:00   18.083363
# ...                   ...         ...
# 6488  2012-12-31 19:00:00  114.205104
# 6489  2012-12-31 20:00:00  126.655695
# 6490  2012-12-31 21:00:00  140.201589
# 6491  2012-12-31 22:00:00  169.456163
# 6492  2012-12-31 23:00:00  163.977042
#
# [6493 rows x 2 columns]

# %%
X_train.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  year hour  \
# 0       1        0           0        1  9.84  14.395        81  2011   00
# 1       1        0           0        1  9.02  13.635        80  2011   01
# 2       1        0           0        1  9.02  13.635        80  2011   02
# 3       1        0           0        1  9.84  14.395        75  2011   03
# 4       1        0           0        1  9.84  14.395        75  2011   04
#
#    weekday
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
